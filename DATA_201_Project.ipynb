# %%
#The dataset is called Arrest.csv, which was retreived from kaggle.com. The dataset shows the citizenship status,
#the amount of checks, the gender and the age of the people who were arrested and recorded. The dataset was updated last year
#and has over 5000 rows of data. Some questions I have inovolving the data are do males have a higher chance getting or getting
#checked and arrested than females?

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
df=pd.read_csv("Arrests.csv")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df.sum
# Out:
# <bound method DataFrame.sum of       Unnamed: 0 released colour  year  age     sex employed citizen  checks
# 0              1      Yes  White  2002   21    Male      Yes     Yes       3
# 1              2       No  Black  1999   17    Male      Yes     Yes       3
# 2              3      Yes  White  2000   24    Male      Yes     Yes       3
# 3              4       No  Black  2000   46    Male      Yes     Yes       1
# 4              5      Yes  Black  1999   27  Female      Yes     Yes       1
# ...          ...      ...    ...   ...  ...     ...      ...     ...     ...
# 5221        5222      Yes  White  2000   17    Male      Yes     Yes       0
# 5222        5223      Yes  White  2000   21  Female      Yes     Yes       0
# 5223        5224      Yes  Black  1999   21  Female      Yes     Yes       1
# 5224        5225       No  Black  1998   24    Male      Yes     Yes       4
# 5225        5226      Yes  White  1999   16    Male      Yes     Yes       3
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# released      object
# colour        object
# year           int64
# age            int64
# sex           object
# employed      object
# citizen       object
# checks         int64
# dtype: object

# %%
df2 = (df[['colour', 'age']])
df2
# Out:
#      colour  age
# 0     White   21
# 1     Black   17
# 2     White   24
# 3     Black   46
# 4     Black   27
# ...     ...  ...
# 5221  White   17
# 5222  White   21
# 5223  Black   21
# 5224  Black   24
# 5225  White   16
#
# [5226 rows x 2 columns]

# %%
df2.set_index('colour')
# Out:
#         age
# colour
# White    21
# Black    17
# White    24
# Black    46
# Black    27
# ...     ...
# White    17
# White    21
# Black    21
# Black    24
# White    16
#
# [5226 rows x 1 columns]

# %%
# %matplotlib inline  
plt.hist(df['sex'])
plt.title("Arrests per Gender")
plt.xlabel("Gender")
plt.ylabel("Arrests")
plt.show()

# %%
df3 = (df[['sex', 'checks']])
df3
# Out:
#          sex  checks
# 0       Male       3
# 1       Male       3
# 2       Male       3
# 3       Male       1
# 4     Female       1
# ...      ...     ...
# 5221    Male       0
# 5222  Female       0
# 5223  Female       1
# 5224    Male       4
# 5225    Male       3
#
# [5226 rows x 2 columns]

# %%
df3.set_index('sex')
# Out:
#         checks
# sex
# Male         3
# Male         3
# Male         3
# Male         1
# Female       1
# ...        ...
# Male         0
# Female       0
# Female       1
# Male         4
# Male         3
#
# [5226 rows x 1 columns]

# %%
ran=df.sample(n = 523)
ran
# Out:
#       Unnamed: 0 released colour  year  age     sex employed citizen  checks
# 1161        1162      Yes  White  2002   22    Male       No     Yes       4
# 96            97      Yes  Black  2001   48    Male      Yes     Yes       3
# 4345        4346       No  White  2002   17    Male      Yes     Yes       0
# 1067        1068       No  White  2001   16    Male      Yes     Yes       3
# 3415        3416      Yes  White  1998   27  Female      Yes     Yes       0
# ...          ...      ...    ...   ...  ...     ...      ...     ...     ...
# 1800        1801      Yes  White  2000   34    Male       No     Yes       3
# 3732        3733      Yes  Black  1999   19  Female      Yes     Yes       0
# 2150        2151      Yes  White  1999   14    Male      Yes     Yes       2
# 3362        3363       No  Black  1997   22    Male       No      No       1
# 1325        1326      Yes  White  2002   16    Male      Yes     Yes       2
#
# [523 rows x 9 columns]

# %%
print("The mean of the sample is:", df["age"].mean())
print("The median of the sample is:", df["age"].median())
# Out:
# The mean of the sample is: 23.846536548029086
# The median of the sample is: 21.0

# %%
df.groupby("sex")['checks'].mean().plot(kind='bar')
plt.title("Average Checks per Gender")
plt.xlabel("Gender")
plt.ylabel("Checks")
plt.show()
